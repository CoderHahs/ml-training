# %% [markdown]
# # Notebook 3 - Simulated annealing for the TSP

# %% [markdown]
# CSI4106 Artificial Intelligence
# Fall 2020
# Prepared by Julian Templeton and Caroline Barrière

# %% [markdown]
# ***INTRODUCTION***:
#
# This homework will allow you to look deeper into one of the randomized searches presented in class, that of *Simulated Annealing*. It is a good example of a *random modification* algorithm, in which we start with a greedy solution, and then make changes and accept the modified solutions with different probabilities given their level of fitness to a cost function.
#
# The application domain for experimenting with *Simulated Annealing* is the traveling salesman problem (TSP), which is a classical problem of scheduling, with optimization on the cost of travel.
#
# The notebook will lead into the **Simulated Annealing** portion after exploring a **greedy approach** and a **randomized greedy approach**.

# %% [markdown]
# ***HOMEWORK***:
# Go through the notebook by running each cell, one at a time.
# Look for **(TO DO)** for the tasks that you need to perform. Do not edit the code outside of the questions which you are asked to answer unless specifically asked. Once you're done, sign the notebook (see the added step at the end), and submit it.
#
# *The notebook will be marked on 20.
# Each **(TO DO)** has a number of points associated with it.*
# ***

# %% [markdown]
# **1. Let's start with a small set of cities.**

# %%
# let's define 5 cities with a label and a (x,y) coordinate
cities = {'A': (0,0), 'B': (1,1), 'C': (1,0), 'D': (1,-1), 'E': (-1,-1)}

# %% [markdown]
# Let's plot the nodes using the *showNodes* method below.
# The packages matplotlib, networkx, and numpy must be installed first.
# To do so, open a command prompt and type **pip install numpy** and **pip install networkx** (If you are using linux or potentially Mac, you may need to use **pip3** rather than **pip** depending on how you set it up). You should already have matplotlib, but if not use the pip command **pip install matplotlib**. After installing the packages, run the cell below. If it does not work, restart the Kernel and run through it again to be able to run the cell.

# %%
import matplotlib.pyplot as plt
import networkx as nx

# small method to show nodes
# provide defaults for figure size (size), as well as x and y axis
def showNodes(nodeDict, size= (6.5, 4), xLim=[-2,2], yLim=[-2,2]):
    fig = plt.figure(figsize=size)
    axg = fig.add_subplot(111)
    axg.set_xlim(xLim)
    axg.set_ylim(yLim)

    G=nx.Graph()
    for k in nodeDict.keys():
        G.add_node(k, coor=nodeDict.get(k))
    
    pos=nx.get_node_attributes(G,'coor')
    nx.draw(G, pos, with_labels = True)
    plt.axis('on')
    plt.show()

# %%
# show the cities on a map
showNodes(cities)

# %% [markdown]
# #### 2. Let's find the distances between all cities.
# First, we define a method to calculate the distance between two specific cities, and then a method to find the distances between all pairs of nodes.

# %%
import math

# returns the euclidian distance between two nodes
def dist(node1, node2):
    return round(math.sqrt(math.pow(node1[0] - node2[0], 2) + math.pow(node1[1] - node2[1], 2)), 3)

# %%
# Small test to see the distance
dist(cities.get('A'), cities.get('B'))
# Out:
# 1.414

# %%
# building a dictionary of all pairs or distances
def distDict(nodes):
    distance = {}
    # go through all pairs of nodes
    for k in nodes.keys():
        for m in nodes.keys():
            distance[k,m] = dist(nodes.get(k), nodes.get(m))
    return distance

# %%
# showing the distances between the cities
distances = distDict(cities)
print(distances)
# Out:
# {('A', 'A'): 0.0, ('A', 'B'): 1.414, ('A', 'C'): 1.0, ('A', 'D'): 1.414, ('A', 'E'): 1.414, ('B', 'A'): 1.414, ('B', 'B'): 0.0, ('B', 'C'): 1.0, ('B', 'D'): 2.0, ('B', 'E'): 2.828, ('C', 'A'): 1.0, ('C', 'B'): 1.0, ('C', 'C'): 0.0, ('C', 'D'): 1.0, ('C', 'E'): 2.236, ('D', 'A'): 1.414, ('D', 'B'): 2.0, ('D', 'C'): 1.0, ('D', 'D'): 0.0, ('D', 'E'): 2.0, ('E', 'A'): 1.414, ('E', 'B'): 2.828, ('E', 'C'): 2.236, ('E', 'D'): 2.0, ('E', 'E'): 0.0}

# %%
# find the min distance from node1 to all other nodes.
# it receives the node1 label, the labels of other nodes to test,
# and the precalculated distances between all nodes
def closestNode(node1_label, otherNodes_Labels, distanceDict):
    # tricky syntax... it creates tuples where the distance is the first element of the tuple
    # and the position in the array is the second element of the tuple
    minDist = min( (distanceDict[node1_label,k], k) for k in otherNodes_Labels)
    # get the second element of the tuple which is the index found
    foundNode = minDist[1]
    return foundNode

# %%
# Testing the closest node
closestNode('B', ['C', 'D'], distances)
# Out:
# 'C'

# %% [markdown]
# #### 3. Greedy solution first
# Before we can apply *simulated annealing*, we must first find a suboptimal solution that we will refine. The first solution will be a Greedy solution. Only the choice of the starting node is random in this solution, and from there, the algorithm always choses the closest node.

# %%
# greedy solution
import random

def greedy_solution(nodes):
    # distance matrix
    allDist = distDict(nodes)
    # pick a first node at random among the set of keys (node names)
    cur_node = random.choice(list(nodes.keys()))
    # add that node to solution
    solution = [cur_node]
    # build a free list of nodes (not yet used) containing all nodes except the one just chosen 
    free_list = list(nodes.keys())
    free_list.remove(cur_node)
    
    # while there are still nodes to be attached
    while free_list:
        # find the closestNode
        found_node = closestNode(cur_node, free_list, allDist)
        cur_node = found_node
        free_list.remove(cur_node)
        solution.append(cur_node)

    return solution

# %%
# Test obtaining a greedy solution
gs = greedy_solution(cities)
print(gs)
# Out:
# ['C', 'A', 'B', 'D', 'E']

# %% [markdown]
# #### 4. Showing a path.
# We slightly modify to showNodes method from before, to become showPath, wich is now a directed graph.

# %%
# small method to show a path
# it receives an ordered list of nodes e.g. ['B','C','A', 'D', 'E']
# and a dictionary of all the nodes and their positions
def showPath(path, nodeDict, size= (6.5, 4), xLim=[-2,2], yLim=[-2,2]):
    fig = plt.figure(figsize=size)
    axg = fig.add_subplot(111)
    axg.set_xlim(xLim)
    axg.set_ylim(yLim)

    G=nx.DiGraph()
    for k in path:
        G.add_node(k, pos=nodeDict.get(k))
        
    for i in range(len(path) - 1):
        x = path[i]
        y = path[i + 1]
        G.add_edge(x,y)
        
    pos=nx.get_node_attributes(G,'pos')
    nx.draw(G, pos, with_labels = True, edge_color = 'b', arrows=True)   
    # nx.draw(G, pos, with_labels = True)
    plt.axis('on')
    plt.show()

# %% [markdown]
# **(TO DO) Q1 - 2 marks**
# 1. Select a seed (integer) to use in the cell below
# 2. Run that cell to set the seed (only once)
# 3. Run the tests below the seed declaration repeatedly (just manually run it) until you get two identical results in the same run. Record how many runs it took and the solution found in the answer section below.
# 4. Run the tests below the seed declaration repeatedly (just manually run it) until you get two different results in the same run. Record how many runs it took and the solution found in the answer section below.

# %% [markdown]
# **(ANSWER in this Markdown) Q1**
# Nb of runs needed to generate an identical gs1 and gs2 :  3
# Solution generated for the identical gs1 and gs2 : ['A', 'C', 'B', 'D', 'E']
#
# Nb of runs needed to generate a different gs1 and gs2 :  1
# Solutions generated for the distinct gs1 and gs2 : ['C', 'A', 'B', 'D', 'E'], ['D', 'C', 'A', 'B', 'E']

# %% [markdown]
# Setup the seed:

# %%
# To Do: Place your seed here and run the cell to set/reset it
# random.seed(int)
random.seed(42)

# %% [markdown]
# Let us run a test to visualize two greedy solutions. Look at the text output of the path if the plotted graph contains edges that go through a node.

# %%
# To Do: Need to run this (make no changes) and answer the questions above

# Testing to output the path chosen by the greedy solution
gs1 = greedy_solution(cities)
print(gs1)
showPath(gs1, cities)
gs2 = greedy_solution(cities)
print(gs2)
showPath(gs2, cities)
# Out:
# ['A', 'C', 'B', 'D', 'E']
# ['A', 'C', 'B', 'D', 'E']

# %% [markdown]
# **(TO DO) Q2 - 2 marks**
# Complete the method to find the total length of the path found.

# %%
# (TO DO) totalDistance, which receives a path (list of node labels) and the dictionary of distances
def totalDist(path, distanceDict):
    total = 0
    for i in range(len(path) - 1):
        x = path[i]
        y = path[i+1]
        total += distanceDict[(x, y)]
    return round(total,3)

# %%
# Test the total distance method
print(totalDist(gs1, distances))
print(totalDist(gs2, distances))
# Out:
# 6.0
# 6.0

# %% [markdown]
# **(TO DO) Q3 - 4 marks**
# Add two more cities (wherever you want within the predefined -2 to +2 axis as long as no other node is already there).  Rerun the full sequence of tasks performed above on the larger set of cities that you will define below: (1) defining the graph (2) showing the points (3) building the distance dictionary, (4) finding two unique greedy solutions, (5) showing the different paths found along with their total distances.

# %%
# (1) Defining a larger set of cities  (add two more)
moreCities = {'A': (0,0), 'B': (1,1), 'C': (1,0), 'D': (1,-1), 'E': (-1,-1), 'F': (-1, 1), 'G': (0,-1)}
# (2) Show the points
showNodes(moreCities)
# (3) Build the distance dictionary
moreDistances = distDict(moreCities)
# (4) Find two unique greedy solutions 
gs3 = greedy_solution(moreCities)
gs4 = greedy_solution(moreCities)
# (5) Show the two unique paths found above along with their total distances
showPath(gs3, moreCities)
print(gs3)
print(totalDist(gs3, moreDistances))
showPath(gs4, moreCities)
print(gs4)
print(totalDist(gs4, moreDistances))
# Out:
# ['F', 'A', 'C', 'B', 'D', 'G', 'E']
# 7.414
# ['C', 'A', 'G', 'D', 'B', 'F', 'E']
# 9.0

# %% [markdown]
# **5. Randomized Greedy - Setup**
#
# Before we create our Randomized Greedy solution, we will define a new function called kClosestNodes that will return the k-closest nodes to a given node.

# %%
# find the min distance from node1 to all other nodes.
# it receives the node1 label, the labels of other nodes to test,
# the precalculated distances between all nodes, and k for how many to return
# The function then outputs a list of the k-closest nodes, where the
# first is the closest and the kth is the kth-closest
def kClosestNodes(node1_label, otherNodes_Labels, distanceDict, k):
    kClosest = []
    # Create a sorted distance list based on the values from the distance dictionary
    # This has the form [((node_1, node_2),value_1), ..., ((node_n, node_n), value_n)]
    sortedDistances = sorted(distanceDict.items(), key=lambda keyPair: keyPair[1])
    # Iterate through the sorted distance list to find our k min distances
    # from node1_label
    for key, value in sortedDistances:
        if (k > 0 and key[0] == node1_label and key[1] in otherNodes_Labels):
            k -= 1
            kClosest.append(key[1])
    return kClosest

# %%
# Example usage
# View the distance dictionary to verify correctness when finding the closest nodes
# to node B in cities
print(distances)
# Find the two closest nodes to the node B in cities (using its distance dictionary)
kClosestNodes('B', ['A', 'C', 'D', 'E'], distances, 2)
# Out:
# {('A', 'A'): 0.0, ('A', 'B'): 1.414, ('A', 'C'): 1.0, ('A', 'D'): 1.414, ('A', 'E'): 1.414, ('B', 'A'): 1.414, ('B', 'B'): 0.0, ('B', 'C'): 1.0, ('B', 'D'): 2.0, ('B', 'E'): 2.828, ('C', 'A'): 1.0, ('C', 'B'): 1.0, ('C', 'C'): 0.0, ('C', 'D'): 1.0, ('C', 'E'): 2.236, ('D', 'A'): 1.414, ('D', 'B'): 2.0, ('D', 'C'): 1.0, ('D', 'D'): 0.0, ('D', 'E'): 2.0, ('E', 'A'): 1.414, ('E', 'B'): 2.828, ('E', 'C'): 2.236, ('E', 'D'): 2.0, ('E', 'E'): 0.0}
# ['C', 'A']

# %% [markdown]
# **6. Randomized Greedy**
#
# Next you will find another suboptimal solution that we will refine. This second solution will be a Randomized Greedy solution.

# %% [markdown]
# **(TO DO) Q4 - 5 marks**
# The Randomized Greedy solution that you will create still selects a random first node, but should now pick randomly among the k closest nodes available, given a probability distribution (rather than the closest node).
#
# For example, if you found the five closest nodes when looking for which to add next, you would randomly choose one of them where the closest nodes would have a higher probability of being chosen then the nodes that are not as close.
#
# The probability distribution for a set of node distances is given by the function *normalize* below and finding the k-closest nodes is given from the kClosestNodes function above. You must call both of these functions in your solution and follow the general structure defined by the comments.
#
# After finishing the function, add one more test to the tests below with a different value for k

# %%
import random
import numpy as np

# DO NOT EDIT THIS FUNCTION
# nodeFrom is the node we start at, nodesTo is a list of nodes
# that nodeFrom can go to, and distDict is the dictionary of all
# combinations of distances.
# This provides the probability distribution to be used by
# randomized_greedy_solution
def normalize(nodeFrom, nodesTo, distDict):
    distances = []
    # Here we normalize by 1/distance^2 
    for nodeTo in nodesTo:
        distances.append(1 / distDict[nodeFrom, nodeTo] ** 2)
    sumOfDistances = sum(distances)
    normalizedDistances = [dist / sumOfDistances for dist in distances]
    return normalizedDistances
    
# k represents the number of closest nodes to be returned from the
# function kClosestNodes
def randomized_greedy_solution(nodes, k):
    # distance matrix
    allDist = distDict(nodes)
    # pick a first node at random among the set of keys (node names)
    cur_node = random.choice(list(nodes.keys()))
    # add that node to solution
    solution = [cur_node]
    # build a free list of nodes (not yet used) containing all nodes except the one just chosen 
    free_list = list(nodes.keys())
    free_list.remove(cur_node)
    
    # while there are still nodes to be attached
    while free_list:
        
        # TO DO START: Complete the algorithm by performing what the comments ask
        
        # Get the closest nodes
        close_nodes = kClosestNodes(cur_node, free_list, allDist, k)
        # Find the normalized distances
        norm_distances = normalize(cur_node, close_nodes, allDist)
        # Select a random closest node based on the probabilities found by the normalized distances
        # You will use the function np.random.choice(options, list_of_probabilities_for_options)
        # For more information on np.random.choice check out the official documentation:
        #      https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.random.choice.html#numpy.random.choice
        found_node = np.random.choice(close_nodes, p = norm_distances)
        # Print out the probabilities for each closest node choice (just output both lists saying what they are)
        print("Probabilites for each closest node choice")
        for i in range (len(norm_distances)):
            print("Node: {0}, probability: {1} ".format(close_nodes[i], norm_distances[i]))
        # Print out the closest node selected by the probability distribution with it's probability of being selected
        print('Random Choice: {0}, probability: {1}'.format(found_node, norm_distances[close_nodes.index(found_node)]))
        # TO DO END
        
        # Same as in the Greedy approach
        cur_node = found_node
        free_list.remove(cur_node)
        solution.append(cur_node)

    return solution

# %%
# Testing to output the path chosen by the randomized greedy solution with various k's to the greedy solution
# Run a few times to see how the results differ with the non-deterministic Randomized Greedy solution
# Note that if they start with the same node and k=1 that the results of both will be the same
print("Greedy Test")
gr = greedy_solution(moreCities)
print(gr)
print(totalDist(gr, moreDistances))
showPath(gr, moreCities)
print("Randomized Greedy Test 1")
rgs1 = randomized_greedy_solution(moreCities, 1)
print(rgs1)
print(totalDist(rgs1, moreDistances))
showPath(rgs1, moreCities)
print("Randomized Greedy Test 2")
rgs2 = randomized_greedy_solution(moreCities, 2)
print(rgs2)
print(totalDist(rgs2, moreDistances))
showPath(rgs2, moreCities)
# TO DO: Add one more test randomized_greedy_solution with a different k
print("Randomized Greedy Test 3")
rgs3 = randomized_greedy_solution(moreCities, 3)
print(rgs3)
print(totalDist(rgs3, moreDistances))
showPath(rgs3, moreCities)
# Out:
# Greedy Test
# ['B', 'C', 'A', 'G', 'D', 'E', 'F']
# 8.0
# Randomized Greedy Test 1
# Probabilites for each closest node choice
# Node: C, probability: 1.0
# Random Choice: C, probability: 1.0
# Probabilites for each closest node choice
# Node: A, probability: 1.0
# Random Choice: A, probability: 1.0
# Probabilites for each closest node choice
# Node: G, probability: 1.0
# Random Choice: G, probability: 1.0
# Probabilites for each closest node choice
# Node: D, probability: 1.0
# Random Choice: D, probability: 1.0
# Probabilites for each closest node choice
# Node: E, probability: 1.0
# Random Choice: E, probability: 1.0
# Probabilites for each closest node choice
# Node: F, probability: 1.0
# Random Choice: F, probability: 1.0
# ['B', 'C', 'A', 'G', 'D', 'E', 'F']
# 8.0
# Randomized Greedy Test 2
# Probabilites for each closest node choice
# Node: C, probability: 0.6665995420411309
# Node: A, probability: 0.3334004579588691
# Random Choice: A, probability: 0.3334004579588691
# Probabilites for each closest node choice
# Node: C, probability: 0.5
# Node: G, probability: 0.5
# Random Choice: G, probability: 0.5
# Probabilites for each closest node choice
# Node: D, probability: 0.5
# Node: E, probability: 0.5
# Random Choice: D, probability: 0.5
# Probabilites for each closest node choice
# Node: C, probability: 0.8
# Node: E, probability: 0.2
# Random Choice: C, probability: 0.8
# Probabilites for each closest node choice
# Node: E, probability: 0.5
# Node: F, probability: 0.5
# Random Choice: E, probability: 0.5
# Probabilites for each closest node choice
# Node: F, probability: 1.0
# Random Choice: F, probability: 1.0
# ['B', 'A', 'G', 'D', 'C', 'E', 'F']
# 8.65
# Randomized Greedy Test 3
# Probabilites for each closest node choice
# Node: A, probability: 0.5000755114022217
# Node: B, probability: 0.2499622442988891
# Node: E, probability: 0.2499622442988891
# Random Choice: A, probability: 0.5000755114022217
# Probabilites for each closest node choice
# Node: C, probability: 0.39997583416153343
# Node: G, probability: 0.39997583416153343
# Node: B, probability: 0.2000483316769332
# Random Choice: G, probability: 0.39997583416153343
# Probabilites for each closest node choice
# Node: D, probability: 0.39997583416153343
# Node: E, probability: 0.39997583416153343
# Node: C, probability: 0.2000483316769332
# Random Choice: D, probability: 0.39997583416153343
# Probabilites for each closest node choice
# Node: C, probability: 0.6666666666666666
# Node: B, probability: 0.16666666666666666
# Node: E, probability: 0.16666666666666666
# Random Choice: E, probability: 0.16666666666666666
# Probabilites for each closest node choice
# Node: C, probability: 0.6153275146799945
# Node: B, probability: 0.3846724853200055
# Random Choice: B, probability: 0.3846724853200055
# Probabilites for each closest node choice
# Node: C, probability: 1.0
# Random Choice: C, probability: 1.0
# ['F', 'A', 'G', 'D', 'E', 'B', 'C']
# 9.242

# %% [markdown]
# **7. Defining the process of simulated annealing**
# The class below defines the simulated annealing process.  This class is an adaptation of the class anneal.py found in the python code provided in this github https://github.com/chncyhn/simulated-annealing-tsp. You are not asked to changed this class, just go through it and try to understand it so as to get a better understanding of the *simulated annealing* algorithm.

# %%
# class to perform a simulated annealing
# must start with a set of nodes, all other parameters have defaults
class SimAnneal(object):
    def __init__(self, nodes, randomizedGreedy, k=4, T=-1, alpha=-1, stopping_T=-1, stopping_iter=-1):
        # set of nodes
        self.nodes = nodes
        # number of nodes
        self.N = len(nodes)
        # set the temperature T to sqrt(N) if not specified
        self.T = math.sqrt(self.N) if T == -1 else T
        # set alpha (rate at which the temperature is decreased)
        self.alpha = 0.995 if alpha == -1 else alpha
        # set stopping temprature
        self.stopping_temperature = 0.00000001 if stopping_T == -1 else stopping_T
        # set stopping iteration
        self.stopping_iter = 100000 if stopping_iter == -1 else stopping_iter
        # start at iteration 1
        self.iteration = 1

        # calculate the distances
        self.allDist = distDict(nodes)
        
        # start with greedy solution if randomizedGreedy is false,
        #  start with the randomized greedy solution if randomizedGreedy is true
        if (randomizedGreedy):
            self.cur_solution = randomized_greedy_solution(nodes, k)
            self.improvementMessage = 'Improvement over randomized greedy heuristic: '
        else:
            self.cur_solution = greedy_solution(nodes)
            self.improvementMessage = 'Improvement over greedy heuristic: '
        
        # so far, the best solution is the one we have
        self.best_solution = list(self.cur_solution)

        # calculate fitness of the current solution
        self.cur_fitness = self.fitness(self.cur_solution)
        # initial fitness for initial solution
        self.initial_fitness = self.cur_fitness
        # best fitness so far
        self.best_fitness = self.cur_fitness
        # build the fitness list as we explore solutions
        self.fitness_list = [self.cur_fitness]


    def fitness(self, sol):
        """ Objective value of a solution """
        return totalDist(sol, self.allDist)

    # acceptance propability
    def p_accept(self, candidate_fitness):
        """
        Probability of accepting if the candidate is worse than current
        Depends on the current temperature and difference between candidate and current
        """
        return math.exp(-abs(candidate_fitness - self.cur_fitness) / self.T)

    def accept(self, candidate):
        """
        Accept with probability 1 if candidate is better than current
        Accept with probabilty p_accept(..) if candidate is worse
        """
        candidate_fitness = self.fitness(candidate)
        # test if fitness is smaller then the current one
        if candidate_fitness < self.cur_fitness:
            self.cur_fitness = candidate_fitness
            self.cur_solution = candidate
            # test if fitness is better than best so far, keep it as best if so
            if candidate_fitness < self.best_fitness:
                self.best_fitness = candidate_fitness
                self.best_solution = candidate

        # if solution is worst than the current one, there is still a possibility to pursue it
        else:
            if random.random() < self.p_accept(candidate_fitness):
                self.cur_fitness = candidate_fitness
                self.cur_solution = candidate

    def anneal(self):
        """
        Execute simulated annealing algorithm
        """
        # go through the temperature schedule
        print(self.T)
        print(self.stopping_temperature)
        while (self.T >= self.stopping_temperature) and (self.iteration < self.stopping_iter):
            # explore current solution
            candidate = list(self.cur_solution)
            # modify the solution to switch two cities
            # first chosen city between [2,N-1] - not changing the first city
            l = random.randint(2, self.N - 1)
            # second city between [0,N-1] Not sure why ??
            i = random.randint(0, self.N - l)
            # the chosen nodes are switch
            candidate[i:(i + l)] = reversed(candidate[i:(i + l)])
            # perform acceptance test 
            self.accept(candidate)
            # multiply the temperature by alpha (this will reduce it)
            self.T *= self.alpha
            self.iteration += 1
            
            # add current fitness to list (to be able to display)
            self.fitness_list.append(self.cur_fitness)

        print('Best fitness obtained: ', self.best_fitness)
        print(self.improvementMessage,
              round((self.initial_fitness - self.best_fitness) / (self.initial_fitness), 4))

        return self.best_solution
    
    def plot_learning(self):
        """
        Plot the fitness through iterations
        """
        plt.plot([i for i in range(len(self.fitness_list))], self.fitness_list)
        plt.ylabel('Fitness')
        plt.xlabel('Iteration')
        plt.show()

# %% [markdown]
# #### 8. Refining a greedy solution through simulated annealing.

# %% [markdown]
# **(TO DO) Q5 - 5 marks**
# Put comments in the code below explaining what it does.  Also run it a few times.  It will show you how there can be improvement (or not) from the greedy solution and randomized greedy solution to the annealed one.

# %%
# Run a greedy solution with moreCities 
firstSol = greedy_solution(moreCities)
# Get all the distances between cities for moreCities
distances = distDict(moreCities)
# Print out solution with total distance
print('Solution {} takes a total of {}'.format(firstSol,totalDist(firstSol, distances)))
# Show path of the solution
showPath(firstSol, moreCities)

# Here we run Simulated Annealling in the hope of finding a better solution. Here the simulated annealing algorithm performs
# multiple greedy solutions. 
sa = SimAnneal(moreCities, False)
# sa.anneal() returns the best possible greedy solution found through the several iterations of switching nodes
# in the hopes of finding one with a better probability.
betterSol = sa.anneal()
# Display the solution found by Simulated Annealing.
showPath(betterSol, moreCities)

# Run a randomized greedy solution with moreCities
secondSol = randomized_greedy_solution(moreCities, 4)
# Print out the solution with total distance
print('Solution {} takes a total of {}'.format(secondSol,totalDist(secondSol, distances)))
# Show solution path
showPath(secondSol, moreCities)

# Here we run Simulated Annealling using randomized greedy solution. In this case k is set to 4 as it was used above. 
sa2 = SimAnneal(moreCities, True, 4)
# sa.anneal() returns the best possible randomized greedy solution found through several iterations.
betterSol2 = sa2.anneal()
# Display the solution found by Simulated Annealing
showPath(betterSol2, moreCities)
# Out:
# Solution ['A', 'C', 'B', 'D', 'G', 'E', 'F'] takes a total of 8.0
# 2.6457513110645907
# 1e-08
# Best fitness obtained:  6.828
# Improvement over greedy heuristic:  0.079
# Probabilites for each closest node choice
# Node: G, probability: 0.4999622414476879
# Node: A, probability: 0.2500566378284682
# Node: D, probability: 0.12499056036192198
# Node: F, probability: 0.12499056036192198
# Random Choice: F, probability: 0.12499056036192198
# Probabilites for each closest node choice
# Node: A, probability: 0.4348476414333376
# Node: B, probability: 0.2173581587228123
# Node: C, probability: 0.17389709992192506
# Node: G, probability: 0.17389709992192506
# Random Choice: A, probability: 0.4348476414333376
# Probabilites for each closest node choice
# Node: C, probability: 0.3332997710205655
# Node: G, probability: 0.3332997710205655
# Node: B, probability: 0.16670022897943457
# Node: D, probability: 0.16670022897943457
# Random Choice: G, probability: 0.3332997710205655
# Probabilites for each closest node choice
# Node: D, probability: 0.5881788267514765
# Node: C, probability: 0.29417825520881136
# Node: B, probability: 0.1176429180397121
# Random Choice: D, probability: 0.5881788267514765
# Probabilites for each closest node choice
# Node: C, probability: 0.8
# Node: B, probability: 0.2
# Random Choice: C, probability: 0.8
# Probabilites for each closest node choice
# Node: B, probability: 1.0
# Random Choice: B, probability: 1.0
# Solution ['E', 'F', 'A', 'G', 'D', 'C', 'B'] takes a total of 7.414
# Probabilites for each closest node choice
# Node: A, probability: 0.2857019559920368
# Node: B, probability: 0.2857019559920368
# Node: D, probability: 0.2857019559920368
# Node: G, probability: 0.14289413202388965
# Random Choice: G, probability: 0.14289413202388965
# Probabilites for each closest node choice
# Node: A, probability: 0.31249881243230865
# Node: D, probability: 0.31249881243230865
# Node: E, probability: 0.31249881243230865
# Node: B, probability: 0.06250356270307407
# Random Choice: A, probability: 0.31249881243230865
# Probabilites for each closest node choice
# Node: B, probability: 0.25
# Node: D, probability: 0.25
# Node: E, probability: 0.25
# Node: F, probability: 0.25
# Random Choice: E, probability: 0.25
# Probabilites for each closest node choice
# Node: D, probability: 0.39997583416153343
# Node: F, probability: 0.39997583416153343
# Node: B, probability: 0.2000483316769332
# Random Choice: F, probability: 0.39997583416153343
# Probabilites for each closest node choice
# Node: B, probability: 0.6665995420411309
# Node: D, probability: 0.3334004579588691
# Random Choice: B, probability: 0.6665995420411309
# Probabilites for each closest node choice
# Node: D, probability: 1.0
# Random Choice: D, probability: 1.0
# 2.6457513110645907
# 1e-08
# Best fitness obtained:  6.828
# Improvement over randomized greedy heuristic:  0.3053

# %% [markdown]
# **9. Moving toward a larger example**
# There are a set of coordinates defined in the file *coord.txt* (available in the Jupyter Notebooks module in Brightspace). This data file is also from the github https://github.com/chncyhn/simulated-annealing-tsp.  It contains a larger example with 45 cities, to test.  Here is the beginning of the file:
#
# 1 0 0
# 2 3 5
# 3 2.5 9
# 4 48 16
# 5 48 17
# 6 69 16
# ...
#
# Make sure to put the file *coord.txt* in the same repertory as your notebook or modify the path below when opening the file to read.  We will assume the first number is the label, and the other two numbers are the coordinates.

# %%
# reading the coordinates
manyCities = {}
with open('coord.txt','r') as f:
    i = 0
    for line in f.readlines():
        line = [float(x.replace('\n','')) for x in line.split(' ')]
        label = str(int(line[0]))
        manyCities[label] = (line[1], line[2])
        i += 1

# %% [markdown]
# Show the nodes from that larger set of cities.

# %%
showNodes(manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# %% [markdown]
# Testing the annealing process with the larger example. The steps are the same as the ones you had to comment in Question 4. Look at the additional step *plot_learning*, it shows the value of the fitness function as the annealing process occurs.  Run it multiple times, it is a probabilistic approach, so the result might be slightly different each time.

# %%
firstSol = greedy_solution(manyCities)
distances = distDict(manyCities)
print('Solution {} takes a total of {}'.format(firstSol,totalDist(firstSol, distances)))
showPath(firstSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

sa = SimAnneal(manyCities, False)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

secondSol = randomized_greedy_solution(manyCities, 3)
print('Solution {} takes a total of {}'.format(secondSol,totalDist(secondSol, distances)))
showPath(firstSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

sa2 = SimAnneal(manyCities, True, 4)
betterSol2 = sa2.anneal()
sa2.plot_learning()
showPath(betterSol2, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])
# Out:
# Solution ['1', '25', '10', '16', '2', '3', '17', '11', '18', '19', '12', '13', '15', '14', '38', '39', '43', '37', '40', '41', '35', '32', '33', '42', '31', '44', '45', '9', '22', '21', '20', '26', '27', '23', '24', '4', '5', '36', '8', '6', '7', '28', '30', '34', '29'] takes a total of 592.589
# 6.708203932499369
# 1e-08
# Best fitness obtained:  509.711
# Improvement over greedy heuristic:  0.1895
# Probabilites for each closest node choice
# Node: 2, probability: 0.4689704744281296
# Node: 17, probability: 0.3763102690930456
# Node: 16, probability: 0.15471925647882473
# Random Choice: 2, probability: 0.4689704744281296
# Probabilites for each closest node choice
# Node: 16, probability: 0.5234815770245258
# Node: 10, probability: 0.32210653570994496
# Node: 25, probability: 0.1544118872655292
# Random Choice: 10, probability: 0.32210653570994496
# Probabilites for each closest node choice
# Node: 16, probability: 0.7433767939183448
# Node: 25, probability: 0.1285023299559744
# Node: 1, probability: 0.1281208761256809
# Random Choice: 16, probability: 0.7433767939183448
# Probabilites for each closest node choice
# Node: 25, probability: 0.47225616397581044
# Node: 1, probability: 0.4699211556167742
# Node: 17, probability: 0.05782268040741533
# Random Choice: 25, probability: 0.47225616397581044
# Probabilites for each closest node choice
# Node: 1, probability: 0.9999978351446367
# Node: 17, probability: 1.1789076867831626e-06
# Node: 22, probability: 9.8594767651574e-07
# Random Choice: 1, probability: 0.9999978351446367
# Probabilites for each closest node choice
# Node: 17, probability: 0.3785658144761002
# Node: 22, probability: 0.3178590708518547
# Node: 21, probability: 0.3035751146720451
# Random Choice: 22, probability: 0.3178590708518547
# Probabilites for each closest node choice
# Node: 21, probability: 0.9979111344744157
# Node: 9, probability: 0.0011076083854185193
# Node: 20, probability: 0.0009812571401658075
# Random Choice: 21, probability: 0.9979111344744157
# Probabilites for each closest node choice
# Node: 9, probability: 0.3767006621382402
# Node: 20, probability: 0.3597253461884748
# Node: 17, probability: 0.26357399167328494
# Random Choice: 9, probability: 0.3767006621382402
# Probabilites for each closest node choice
# Node: 20, probability: 0.4109467725736635
# Node: 45, probability: 0.29680860577326074
# Node: 44, probability: 0.29224462165307574
# Random Choice: 20, probability: 0.4109467725736635
# Probabilites for each closest node choice
# Node: 26, probability: 0.6946392535017436
# Node: 11, probability: 0.15331208363043516
# Node: 17, probability: 0.1520486628678213
# Random Choice: 17, probability: 0.1520486628678213
# Probabilites for each closest node choice
# Node: 11, probability: 0.5029938078089501
# Node: 18, probability: 0.34603191470969
# Node: 19, probability: 0.15097427748135991
# Random Choice: 18, probability: 0.34603191470969
# Probabilites for each closest node choice
# Node: 11, probability: 0.5217769328126872
# Node: 19, probability: 0.41974724995099405
# Node: 12, probability: 0.058475817236318825
# Random Choice: 19, probability: 0.41974724995099405
# Probabilites for each closest node choice
# Node: 11, probability: 0.8047173961201041
# Node: 12, probability: 0.1252872144549729
# Node: 13, probability: 0.06999538942492295
# Random Choice: 11, probability: 0.8047173961201041
# Probabilites for each closest node choice
# Node: 26, probability: 0.3408782786385309
# Node: 12, probability: 0.33738129913382375
# Node: 38, probability: 0.3217404222276453
# Random Choice: 38, probability: 0.3217404222276453
# Probabilites for each closest node choice
# Node: 39, probability: 0.9453736506025078
# Node: 37, probability: 0.029081494741726124
# Node: 43, probability: 0.02554485465576628
# Random Choice: 39, probability: 0.9453736506025078
# Probabilites for each closest node choice
# Node: 43, probability: 0.4658236771459757
# Node: 37, probability: 0.45703534933832407
# Node: 40, probability: 0.07714097351570022
# Random Choice: 37, probability: 0.45703534933832407
# Probabilites for each closest node choice
# Node: 43, probability: 0.6753578455686171
# Node: 40, probability: 0.16770719422486263
# Node: 41, probability: 0.1569349602065203
# Random Choice: 43, probability: 0.6753578455686171
# Probabilites for each closest node choice
# Node: 40, probability: 0.40687421504797755
# Node: 41, probability: 0.37252396533429677
# Node: 42, probability: 0.2206018196177256
# Random Choice: 40, probability: 0.40687421504797755
# Probabilites for each closest node choice
# Node: 41, probability: 0.9900053799006964
# Node: 35, probability: 0.006186663624807113
# Node: 42, probability: 0.003807956474496648
# Random Choice: 41, probability: 0.9900053799006964
# Probabilites for each closest node choice
# Node: 35, probability: 0.5116568365331655
# Node: 42, probability: 0.27269175012092955
# Node: 31, probability: 0.21565141334590493
# Random Choice: 42, probability: 0.27269175012092955
# Probabilites for each closest node choice
# Node: 31, probability: 0.9836500600949353
# Node: 32, probability: 0.008480260947824697
# Node: 35, probability: 0.007869678957240082
# Random Choice: 31, probability: 0.9836500600949353
# Probabilites for each closest node choice
# Node: 32, probability: 0.3612161696588694
# Node: 33, probability: 0.329539860926615
# Node: 35, probability: 0.30924396941451565
# Random Choice: 33, probability: 0.329539860926615
# Probabilites for each closest node choice
# Node: 32, probability: 0.9686110114035743
# Node: 35, probability: 0.022781713121953363
# Node: 34, probability: 0.008607275474472268
# Random Choice: 32, probability: 0.9686110114035743
# Probabilites for each closest node choice
# Node: 35, probability: 0.6826939084512682
# Node: 36, probability: 0.16250021661647154
# Node: 34, probability: 0.15480587493226033
# Random Choice: 35, probability: 0.6826939084512682
# Probabilites for each closest node choice
# Node: 36, probability: 0.47872512662522987
# Node: 4, probability: 0.27508538256777343
# Node: 5, probability: 0.24618949080699667
# Random Choice: 5, probability: 0.24618949080699667
# Probabilites for each closest node choice
# Node: 4, probability: 0.9872495601510906
# Node: 36, probability: 0.00912065990492273
# Node: 8, probability: 0.003629779943986727
# Random Choice: 4, probability: 0.9872495601510906
# Probabilites for each closest node choice
# Node: 36, probability: 0.6421264739525847
# Node: 8, probability: 0.22354237857772924
# Node: 6, probability: 0.134331147469686
# Random Choice: 8, probability: 0.22354237857772924
# Probabilites for each closest node choice
# Node: 6, probability: 0.4905915599353851
# Node: 7, probability: 0.37069783308754545
# Node: 36, probability: 0.13871060697706944
# Random Choice: 7, probability: 0.37069783308754545
# Probabilites for each closest node choice
# Node: 6, probability: 0.9909966623130679
# Node: 28, probability: 0.005829754124691813
# Node: 36, probability: 0.0031735835622403786
# Random Choice: 6, probability: 0.9909966623130679
# Probabilites for each closest node choice
# Node: 28, probability: 0.5046235658114907
# Node: 36, probability: 0.3462415310517256
# Node: 30, probability: 0.14913490313678374
# Random Choice: 28, probability: 0.5046235658114907
# Probabilites for each closest node choice
# Node: 30, probability: 0.6510948197581623
# Node: 36, probability: 0.20176563181711168
# Node: 34, probability: 0.14713954842472612
# Random Choice: 30, probability: 0.6510948197581623
# Probabilites for each closest node choice
# Node: 34, probability: 0.6164646876252771
# Node: 36, probability: 0.2988357066563635
# Node: 44, probability: 0.08469960571835942
# Random Choice: 34, probability: 0.6164646876252771
# Probabilites for each closest node choice
# Node: 36, probability: 0.5102069137545692
# Node: 44, probability: 0.2451349645828903
# Node: 45, probability: 0.2446581216625405
# Random Choice: 44, probability: 0.2451349645828903
# Probabilites for each closest node choice
# Node: 45, probability: 0.9990338728582967
# Node: 36, probability: 0.0006235229329041326
# Node: 26, probability: 0.0003426042087991415
# Random Choice: 45, probability: 0.9990338728582967
# Probabilites for each closest node choice
# Node: 36, probability: 0.5407099292617676
# Node: 26, probability: 0.30701307018251484
# Node: 27, probability: 0.15227700055571738
# Random Choice: 36, probability: 0.5407099292617676
# Probabilites for each closest node choice
# Node: 15, probability: 0.33862375100508907
# Node: 13, probability: 0.33140005572685577
# Node: 14, probability: 0.3299761932680551
# Random Choice: 15, probability: 0.33862375100508907
# Probabilites for each closest node choice
# Node: 13, probability: 0.5539459359827119
# Node: 14, probability: 0.4431836943547862
# Node: 12, probability: 0.0028703696625019095
# Random Choice: 14, probability: 0.4431836943547862
# Probabilites for each closest node choice
# Node: 13, probability: 0.9934471273772398
# Node: 12, probability: 0.006327236893044051
# Node: 26, probability: 0.00022563572971602945
# Random Choice: 13, probability: 0.9934471273772398
# Probabilites for each closest node choice
# Node: 12, probability: 0.952343428322137
# Node: 26, probability: 0.030310611264950243
# Node: 27, probability: 0.017345960412912684
# Random Choice: 12, probability: 0.952343428322137
# Probabilites for each closest node choice
# Node: 26, probability: 0.47864208619696147
# Node: 27, probability: 0.2645869313711847
# Node: 23, probability: 0.25677098243185387
# Random Choice: 26, probability: 0.47864208619696147
# Probabilites for each closest node choice
# Node: 27, probability: 0.36240245774960184
# Node: 23, probability: 0.3274377370724676
# Node: 24, probability: 0.3101598051779306
# Random Choice: 24, probability: 0.3101598051779306
# Probabilites for each closest node choice
# Node: 23, probability: 0.8332943489592972
# Node: 27, probability: 0.16666900326725806
# Node: 29, probability: 3.664777344468167e-05
# Random Choice: 23, probability: 0.8332943489592972
# Probabilites for each closest node choice
# Node: 27, probability: 0.9999110070888495
# Node: 29, probability: 8.89929111505262e-05
# Random Choice: 27, probability: 0.9999110070888495
# Probabilites for each closest node choice
# Node: 29, probability: 1.0
# Random Choice: 29, probability: 1.0
# Solution ['3', '2', '10', '16', '25', '1', '22', '21', '9', '20', '17', '18', '19', '11', '38', '39', '37', '43', '40', '41', '42', '31', '33', '32', '35', '5', '4', '8', '7', '6', '28', '30', '34', '44', '45', '36', '15', '14', '13', '12', '26', '24', '23', '27', '29'] takes a total of 724.431
# Probabilites for each closest node choice
# Node: 20, probability: 0.5071105591813143
# Node: 21, probability: 0.16807355580509317
# Node: 27, probability: 0.1625461338832613
# Node: 22, probability: 0.1622697511303312
# Random Choice: 20, probability: 0.5071105591813143
# Probabilites for each closest node choice
# Node: 21, probability: 0.32502424920355827
# Node: 22, probability: 0.3119096243736898
# Node: 9, probability: 0.2439960097428648
# Node: 1, probability: 0.11907011667988723
# Random Choice: 22, probability: 0.3119096243736898
# Probabilites for each closest node choice
# Node: 21, probability: 0.9934315392915514
# Node: 1, probability: 0.0024530665274116606
# Node: 25, probability: 0.0024486840959017987
# Node: 10, probability: 0.0016667100851353973
# Random Choice: 21, probability: 0.9934315392915514
# Probabilites for each closest node choice
# Node: 1, probability: 0.30298352562214426
# Node: 25, probability: 0.30251323694544563
# Node: 10, probability: 0.20555879192626192
# Node: 16, probability: 0.18894444550614814
# Random Choice: 1, probability: 0.30298352562214426
# Probabilites for each closest node choice
# Node: 25, probability: 0.9999707671244443
# Node: 10, probability: 1.3788422972300652e-05
# Node: 16, probability: 1.2503410619062514e-05
# Node: 2, probability: 2.941041964350071e-06
# Random Choice: 25, probability: 0.9999707671244443
# Probabilites for each closest node choice
# Node: 10, probability: 0.4530684262871687
# Node: 16, probability: 0.41166053107687967
# Node: 2, probability: 0.09664980899608289
# Node: 17, probability: 0.03862123363986865
# Random Choice: 16, probability: 0.41166053107687967
# Probabilites for each closest node choice
# Node: 10, probability: 0.8549762359027321
# Node: 2, probability: 0.10688430055162554
# Node: 3, probability: 0.02169756124978969
# Node: 17, probability: 0.016441902295852743
# Random Choice: 10, probability: 0.8549762359027321
# Probabilites for each closest node choice
# Node: 2, probability: 0.6694900670379015
# Node: 3, probability: 0.16997684358103507
# Node: 36, probability: 0.10893295950529498
# Random Choice: 35, probability: 0.295350037535594
# Probabilites for each closest node choice
# Node: 36, probability: 0.6324077139509292
# Node: 44, probability: 0.14834484119889707
# Node: 45, probability: 0.14155918121803845
# Node: 30, probability: 0.07768826363213535
# Random Choice: 36, probability: 0.6324077139509292
# Probabilites for each closest node choice
# Node: 28, probability: 0.38038051544102763
# Node: 30, probability: 0.27899960605068913
# Node: 44, probability: 0.17313259703242648
# Node: 45, probability: 0.1674872814758567
# Random Choice: 45, probability: 0.1674872814758567
# Probabilites for each closest node choice
# Node: 44, probability: 0.9972542951766165
# Node: 9, probability: 0.002216163161957483
# Node: 30, probability: 0.0002822688325145155
# Node: 28, probability: 0.00024727282891169047
# Random Choice: 44, probability: 0.9972542951766165
# Probabilites for each closest node choice
# Node: 9, probability: 0.7561749928147138
# Node: 30, probability: 0.09851499075277123
# Node: 28, probability: 0.08687544109090219
# Node: 27, probability: 0.05843457534161276
# Random Choice: 9, probability: 0.7561749928147138
# Probabilites for each closest node choice
# Node: 27, probability: 0.29775099139499617
# Node: 23, probability: 0.2851799122125173
# Node: 24, probability: 0.2756856076492103
# Node: 30, probability: 0.1413834887432764
# Random Choice: 24, probability: 0.2756856076492103
# Probabilites for each closest node choice
# Node: 23, probability: 0.8332538297319961
# Node: 27, probability: 0.16666089892905409
# Node: 30, probability: 4.3568932835650474e-05
# Node: 28, probability: 4.170240611416461e-05
# Random Choice: 23, probability: 0.8332538297319961
# Probabilites for each closest node choice
# Node: 27, probability: 0.9997036323315533
# Node: 30, probability: 0.00010600381013965532
# Node: 28, probability: 0.00010138940368225599
# Node: 29, probability: 8.897445462467531e-05
# Random Choice: 27, probability: 0.9997036323315533
# Probabilites for each closest node choice
# Node: 30, probability: 0.3587708943420535
# Node: 28, probability: 0.34339106501930805
# Node: 29, probability: 0.29783804063863845
# Random Choice: 29, probability: 0.29783804063863845
# Probabilites for each closest node choice
# Node: 30, probability: 0.5742880197660775
# Node: 28, probability: 0.4257119802339226
# Random Choice: 30, probability: 0.5742880197660775
# Probabilites for each closest node choice
# Node: 28, probability: 1.0
# Random Choice: 28, probability: 1.0
# 6.708203932499369
# 1e-08
# Best fitness obtained:  554.493
# Improvement over randomized greedy heuristic:  0.268

# %% [markdown]
# **(TO DO) Q6 - 2 marks**
# Try the annealing again, but provide a different temperature schedule, by changing alpha, and the starting and stopping temperatures.  These are all parameters to the class which can be set.  Try also changing the number of iterations to do.  Explore 4 variations below.

# %%
# (TO DO) Look at this line from the SimAnneal class above
# def __init__(self, nodes, randomizedGreedy, k=4, T=-1, alpha=-1, stopping_T=-1, stopping_iter=-1):
# This means that parameters k, T, alpha, stopping_T and stopping_iter all have defaults, but could be changed
# For example, calling SimAnneal(manyCities, False, stopping_iter=100) means that I set a maximum of 100 iterations for a 
# Greedy solution. Calling  SimAnneal(manyCities, True, k=3, stopping_iter=100) is the same for a randomized greedy solution
# with k = 3.
# Try four variations and look at the differences
# The key point of this question is to use different parameters to understand how they work
# What you need to do is create and run these four different examples

# Test 1 (Use a Greedy solution, see comment above) ...
sa = SimAnneal(manyCities, False, stopping_T=-1000, stopping_iter=100000)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# Test 2 (Use a Randomized Greedy solution, see comment above)...
sa = SimAnneal(manyCities, True, k = 10, stopping_T=-1000, stopping_iter=100000)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# Test 3 (Use a Greedy solution, see comment above)...
sa = SimAnneal(manyCities, True, k = 10, T = -1000, alpha = 1, stopping_T=-1000, stopping_iter=100000)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# Test 4 (Use a Randomized Greedy solution, see comment above)...
sa = SimAnneal(manyCities, True, k = 10, T = -1000, alpha = 10, stopping_T=-10000, stopping_iter=100000)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])
# Out:
# 6.708203932499369
# -1000
# Best fitness obtained:  529.153
# Improvement over greedy heuristic:  0.1056
# Probabilites for each closest node choice
# Node: 22, probability: 0.9878972285489578
# Node: 1, probability: 0.0023297789013313865
# Node: 25, probability: 0.0023261626366045908
# Node: 10, probability: 0.0015806355656783325
# Node: 16, probability: 0.0014528802573013852
# Node: 9, probability: 0.0010600224446717138
# Node: 20, probability: 0.0010122545012600786
# Node: 2, probability: 0.0009498440993199521
# Node: 17, probability: 0.0007416879636459635
# Node: 3, probability: 0.0006495050812287691
# Random Choice: 22, probability: 0.9878972285489578
# Probabilites for each closest node choice
# Node: 1, probability: 0.18760002294386233
# Node: 25, probability: 0.18726487334942085
# Node: 10, probability: 0.12746284975079106
# Node: 16, probability: 0.11634392832265084
# Node: 9, probability: 0.08432490703485512
# Node: 2, probability: 0.07529933309047064
# Node: 20, probability: 0.07470548093630028
# Node: 17, probability: 0.057510647858888556
# Node: 3, probability: 0.05092159895090079
# Node: 11, probability: 0.03856635776185969
# Random Choice: 16, probability: 0.11634392832265084
# Probabilites for each closest node choice
# Node: 10, probability: 0.668364881384078
# Node: 25, probability: 0.10497625056205571
# Node: 1, probability: 0.10445720932710587
# Node: 2, probability: 0.08355520289353936
# Node: 3, probability: 0.016961743896574556
# Node: 17, probability: 0.012853211137609238
# Node: 11, probability: 0.002650061032063148
# Node: 38, probability: 0.0023078216568274985
# Node: 39, probability: 0.0020885132649977813
# Node: 18, probability: 0.001785104845148945
# Random Choice: 25, probability: 0.10497625056205571
# Probabilites for each closest node choice
# Node: 1, probability: 0.9999797306743962
# Node: 10, probability: 1.3829599159950938e-05
# Node: 2, probability: 2.9501683184041844e-06
# Node: 17, probability: 1.1788863432378252e-06
# Node: 3, probability: 1.1485100985824058e-06
# Node: 11, probability: 3.3219434782263655e-07
# Node: 38, probability: 2.2224293311696186e-07
# Node: 39, probability: 2.0492727509736727e-07
# Node: 9, probability: 2.0264582563031817e-07
# Node: 18, probability: 2.0015130197426125e-07
# Random Choice: 1, probability: 0.9999797306743962
# Probabilites for each closest node choice
