# %%
import json
with open('../../../../CORD-19/pmc_custom_license/pmc_custom_license/4630cc2a962fc78b5f438c4d95f9163f2ee7e189.json') as json_file:
    data = json.load(json_file)

# %%
data
# Out:
# {'paper_id': '4630cc2a962fc78b5f438c4d95f9163f2ee7e189',
#  'metadata': {'title': 'Rapid identification of novel antigens of Salmonella Enteritidis by microarray-based immunoscreening',
#   'authors': [{'first': 'Lena',
#     'middle': [],
#     'last': 'Danckert',
#     'suffix': '',
#     'affiliation': {},
#     'email': ''},
#    {'first': 'Sebastian',
#     'middle': [],
#     'last': 'Hoppe',
#     'suffix': '',
#     'affiliation': {},
#     'email': ''},
#    {'first': 'Frank',
#     'middle': ['F'],
#     'last': 'Bier',
#     'suffix': '',
#     'affiliation': {},
#     'email': ''},
#    {'first': 'Markus',
#     'middle': [],
#     'last': 'Von Nickisch-Rosenegk',
#     'suffix': '',
#     'affiliation': {},
#     'email': ''}]},
# ...
